# %% [markdown]
# # Plot EMU adjoint output

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:33821")
client
# Out:
# <Client: 'tcp://127.0.0.1:33821' processes=4 threads=8, memory=61.46 GiB>

# %%
import numpy as np
import ecco_v4_py as ecco
import xarray as xr
import matplotlib.pyplot as plt
import ecco_access as ea
from os.path import join,expanduser

# identify user's home directory
user_home_dir = expanduser('~')

# %% [markdown]
# ### Directories of adjoint outputs:
#
# `/efs_ecco/nrosenbe/emu_adj_3_3_1_89_1082_1` <br>
# `/efs_ecco/nrosenbe/emu_adj_1_1_1_drake_ssh_mask.bin_1`

# %% [markdown]
# ### Plot

# %% [markdown]
# Using Ichiro's functions:

# %%
import runpy
runpy.run_path('/efs_ecco/ECCO/EMU/emu_userinterface_dir/python/emu_plot.py');
# Out:
# Found file: /efs_ecco/ECCO/EMU/emu_userinterface_dir/emu_env.singularity
# EMU Input Files directory: /efs/owang/ECCO/EMU_test/emu_input_dir
# Enter directory of EMU run to examine; e.g., emu_samp_m_2_45_585_1 ... ?  /efs_ecco/nrosenbe/emu_adj_1_1_1_drake_ssh_mask.bin_1
# Reading /efs_ecco/nrosenbe/emu_adj_1_1_1_drake_ssh_mask.bin_1
#
# Reading Adjoint Tool output ...
#
# Choose control to plot ...
# 1) empmr
# 2) pload
# 3) qnet
# 4) qsw
# 5) saltflux
# 6) spflx
# 7) tauu
# 8) tauv
# Enter control # to plot ... (1-8)?  8
# Plotting control ... tauv
# Found file: adxx_tauv.0000000129.data
#
# *********************************************
# Read adjoint gradient for tauv
#    adxx: adjoint gradient as a function of space and lag
# from file /efs_ecco/nrosenbe/emu_adj_1_1_1_drake_ssh_mask.bin_1/output/adxx_tauv.0000000129.data
#
# Zero lag at (week/record) = 6
# Max  lag at (week/record) = 3
#
# *********************************************
# Plotting maps of adxx at select lags ...
# ...

# %% [markdown]
# Use ecco tools

# %%
file_dir = '/efs_ecco/nrosenbe/emu_adj_1_1_1_drake_ssh_mask.bin_1/output'
filename = 'adxx_tauv.0000000129.data'

# %%
ssh_adjoint_tiles = ecco.read_llc_to_tiles(file_dir, filename)
# Out:
# load_binary_array: loading file /efs_ecco/nrosenbe/emu_adj_1_1_1_drake_ssh_mask.bin_1/output/adxx_tauv.0000000129.data
# load_binary_array: data array shape  (1170, 90)
# load_binary_array: data array type  >f4
# llc_compact_to_faces: dims, llc  (1170, 90) 90
# llc_compact_to_faces: data_compact array type  >f4
# llc_faces_to_tiles: data_tiles shape  (13, 90, 90)
# llc_faces_to_tiles: data_tiles dtype  >f4

# %%
ecco.plot_tiles(ssh_adjoint_tiles, layout='latlon',rotate_to_latlon=True,show_tile_labels=True, show_colorbar=True);
